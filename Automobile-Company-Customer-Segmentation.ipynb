# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Sales_Data.xlsx")

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#    ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0 2018-02-24                   828  Shipped  Motorcycles    95    S10_1678
# 1 2018-05-07                   757  Shipped  Motorcycles    95    S10_1678
# 2 2018-07-01                   703  Shipped  Motorcycles    95    S10_1678
# 3 2018-08-25                   649  Shipped  Motorcycles    95    S10_1678
# 4 2018-10-28                   586  Shipped  Motorcycles    95    S10_1678
#
#            CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# ...

# %%
df.shape
# Out:
# (2747, 20)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDERNUMBER           2747 non-null   int64
#  1   QUANTITYORDERED       2747 non-null   int64
#  2   PRICEEACH             2747 non-null   float64
#  3   ORDERLINENUMBER       2747 non-null   int64
#  4   SALES                 2747 non-null   float64
#  5   ORDERDATE             2747 non-null   datetime64[ns]
#  6   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  7   STATUS                2747 non-null   object
#  8   PRODUCTLINE           2747 non-null   object
#  9   MSRP                  2747 non-null   int64
#  10  PRODUCTCODE           2747 non-null   object
#  11  CUSTOMERNAME          2747 non-null   object
#  12  PHONE                 2747 non-null   object
#  13  ADDRESSLINE1          2747 non-null   object
#  14  CITY                  2747 non-null   object
# ...

# %%
df.describe(include='all').T
# Out:
# C:\Users\rkeswani\AppData\Local\Temp\ipykernel_13492\377021028.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all').T
#                        count unique                    top  freq      first  \
# ORDERNUMBER           2747.0    NaN                    NaN   NaN        NaT
# QUANTITYORDERED       2747.0    NaN                    NaN   NaN        NaT
# PRICEEACH             2747.0    NaN                    NaN   NaN        NaT
# ORDERLINENUMBER       2747.0    NaN                    NaN   NaN        NaT
# SALES                 2747.0    NaN                    NaN   NaN        NaT
# ORDERDATE               2747    246    2018-11-14 00:00:00    38 2018-01-06
# DAYS_SINCE_LASTORDER  2747.0    NaN                    NaN   NaN        NaT
# ...

# %%
df.loc[df[(df['CUSTOMERNAME']=='Land of Toys Inc.') & (df['CUSTOMERNAME']=='Land of Toys Inc.')].index,['CUSTOMERNAME','CONTACTFIRSTNAME','PRODUCTCODE','ORDERDATE','DAYS_SINCE_LASTORDER']].sort_values(by='ORDERDATE')
# Out:
#            CUSTOMERNAME CONTACTFIRSTNAME PRODUCTCODE  ORDERDATE  \
# 0     Land of Toys Inc.             Kwai    S10_1678 2018-02-24
# 1415  Land of Toys Inc.             Kwai    S24_1578 2018-02-24
# 1510  Land of Toys Inc.             Kwai    S24_2000 2018-02-24
# 773   Land of Toys Inc.             Kwai    S18_2625 2018-02-24
# 226   Land of Toys Inc.             Kwai    S12_2823 2018-02-24
# 2104  Land of Toys Inc.             Kwai    S32_1374 2018-02-24
# 74    Land of Toys Inc.             Kwai    S10_4698 2018-02-24
# 50    Land of Toys Inc.             Kwai    S10_2016 2018-02-24
# 2448  Land of Toys Inc.             Kwai   S700_1938 2019-05-07
# 2396  Land of Toys Inc.             Kwai   S700_1138 2019-05-07
# 2628  Land of Toys Inc.             Kwai   S700_3505 2019-05-07
# 1891  Land of Toys Inc.             Kwai    S24_3816 2019-05-07
# 1771  Land of Toys Inc.             Kwai    S24_3151 2019-05-07
# 1547  Land of Toys Inc.             Kwai    S24_2011 2019-05-07
# ...

# %%
df = pd.read_excel("RFM.xlsx")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df.head()
# Out:
#               CUSTOMERNAME  ORDERNUMBER      SALES  Days_since_last_order  \
# 0           AV Stores, Co.         51.0  157807.81                 1225.0
# 1             Alpha Cognac         20.0   70488.44                 1093.0
# 2       Amica Models & Co.         26.0   94117.26                 1294.0
# 3  Anna's Decorations, Ltd         46.0  153996.13                 1112.0
# 4        Atelier graphique          7.0   24179.96                 1217.0
#
#   ORDERNUMBER [Binned] SALES [Binned] Days_since_last_order [Binned] RFM_M  \
# 0                Bin 4          Bin 4                          Bin 3     H
# 1                Bin 1          Bin 1                          Bin 1     L
# 2                Bin 2          Bin 3                          Bin 4    MH
# 3                Bin 4          Bin 4                          Bin 2     H
# 4                Bin 1          Bin 1                          Bin 3     L
#
#   RFM_F RFM_R
# 0     H    ML
# 1     L     H
# 2    ML     L
# ...

# %%
pd.crosstab([df['RFM_R'],df['RFM_F']],df['RFM_M']).reindex([('H','H'),('H','MH'),('H','ML'),('H','L'),('MH','H'),('MH','MH'),('MH','ML'),('MH','L'),('ML','H'),('ML','MH'),('ML','ML'),('ML','L'),('L','H'),('L','MH'),('L','ML'),('L','L')], axis=0).reindex(['H','MH','ML','L'], axis=1)
# Out:
# RFM_M        H  MH  ML   L
# RFM_R RFM_F
# H     H      9   1   0   0
#       MH     1   3   0   0
#       ML     0   1   4   1
#       L      0   0   2   1
# MH    H      6   1   0   0
#       MH     0   4   1   0
#       ML     0   2   2   0
#       L      0   0   0   6
# ML    H      4   0   0   0
#       MH     1   2   0   0
#       ML     0   4   6   1
#       L      0   0   2   2
# L     H      1   0   0   0
#       MH     0   3   0   0
#       ML     0   1   3   0
#       L      0   0   2  12
